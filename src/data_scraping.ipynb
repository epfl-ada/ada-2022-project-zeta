# %%
from selenium import webdriver

# %%
url = "https://politpro.eu/en/"
country = "Norway".lower()

# %%
# webdriver.Firefox() if Chrome not installed
driver = webdriver.Chrome()
driver.get(url + country)
data = driver.execute_script("return data")

# %%
data
# Out:
# [{'avg': 23.8,
#   'color': '#E31836',
#   'development': [{'x': '2022-12-11', 'y': 17.4},
#    {'x': '2022-12-04', 'y': 17.7},
#    {'x': '2022-11-27', 'y': 17.7},
#    {'x': '2022-11-20', 'y': 17.1},
#    {'x': '2022-11-13', 'y': 18},
#    {'x': '2022-11-06', 'y': 18.7},
#    {'x': '2022-10-30', 'y': 18.7},
#    {'x': '2022-10-23', 'y': 19.1},
#    {'x': '2022-10-16', 'y': 20.8},
#    {'x': '2022-10-09', 'y': 19.8},
#    {'x': '2022-10-02', 'y': 19.8},
#    {'x': '2022-09-25', 'y': 20.4},
#    {'x': '2022-09-18', 'y': 20.9},
#    {'x': '2022-09-11', 'y': 20.5},
#    {'x': '2022-09-04', 'y': 20.5},
#    {'x': '2022-08-28', 'y': 20.2},
#    {'x': '2022-08-21', 'y': 20.2},
#    {'x': '2022-08-14', 'y': 20.2},
#    {'x': '2022-08-07', 'y': 21},
#    {'x': '2022-07-31', 'y': 21.8},
#    {'x': '2022-07-24', 'y': 21.8},
#    {'x': '2022-07-17', 'y': 21.8},
#    {'x': '2022-07-10', 'y': 21.8},
#    {'x': '2022-07-03', 'y': 21.8},
#    {'x': '2022-06-26', 'y': 21.2},
# ...
